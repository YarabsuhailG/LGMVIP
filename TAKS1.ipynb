# %% [markdown]
# **Import necessary libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# **STEP:1 Load and Prepare the Dataset**

# %%
df = pd.read_csv('/content/Iris.csv')

# %% [markdown]
# **Display the first few rows of the dataset**

# %%
print("Dataset Preview:")
print(df.head())
# Out:
# Dataset Preview:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# **Assume the last column is the target variable, and the rest are features**

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# **Print dataset dimensions and target classes**

# %%
print("\nDataset dimensions:")
print(f"Features: {X.shape}")
print(f"Target: {y.shape}")
# Out:
# Dataset dimensions:
# Features: (150, 5)
# Target: (150,)

# %% [markdown]
# **STEP:2 Split the Data into Training and Testing Sets**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# **STEP 3: Create and Train the Decision Tree Classifier**

# %%
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# **STEP 4: Evaluate the Classifier**

# %%
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("\nModel Evaluation:")
print(f"Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Model Evaluation:
# Accuracy: 1.00
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# **STEP 5: Visualize the Decision Tree**

# %%
plt.figure(figsize=(20, 10))
plot_tree(clf, filled=True, feature_names=df.columns[:-1], class_names=np.unique(y).astype(str))
plt.title('Decision Tree Visualization')
plt.show()

# %% [markdown]
# **STEP 6: Make Predictions on New Data**

# %%
# Example new data (replace with your own feature values)
new_data = np.array([[5.1, 3.5, 1.4, 0.2],  # Adjust based on your feature set
                     [6.7, 3.0, 5.2, 2.3]]) # Adjust based on your feature set

# %% [markdown]
# **Make predictions**

# %%
predictions = clf.predict(new_data)

# %% [markdown]
# **Print the predictions**

# %%
print("\nPredictions for New Data:")
for i, data in enumerate(new_data):
    print(f"Data: {data} - Predicted class: {predictions[i]}")
# Out:
# Predictions for New Data:
# Data: [5.1 3.5 1.4 0.2 1. ] - Predicted class: Iris-setosa
# Data: [6.7 3.  5.2 2.3 2. ] - Predicted class: Iris-setosa
